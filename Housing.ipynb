# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn import *
from importlib import reload
plt=reload(plt)
from mpl_toolkits.basemap import Basemap

# %%
df = pd.read_csv('Carlifonia_census_data (1).csv')
# The head function is used to look at the first five rows in a dataframe
df.head()
# Out:
#    longitude  latitude  housing_median_age total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41         880           129.0
# 1    -122.22     37.86                  21        7099          1106.0
# 2    -122.24     37.85                  52        1467           190.0
# 3    -122.25     37.85                  52        1274           235.0
# 4    -122.25     37.85                  52        1627           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0         322         126         8.3252              452600        NEAR BAY
# 1        2401        1138         8.3014              358500        NEAR BAY
# 2         496         177         7.2574              352100        NEAR BAY
# 3         558         219         5.6431              341300        NEAR BAY
# 4         565         259         3.8462              342200        NEAR BAY

# %%
# Prints out all the columns in the dataframe
data_columns = list(df.columns)
data_columns
# Out:
# ['longitude',
#  'latitude',
#  'housing_median_age',
#  'total_rooms',
#  'total_bedrooms',
#  'population',
#  'households',
#  'median_income',
#  'median_house_value',
#  'ocean_proximity']

# %%
# The tail function is used to check the last five rows of the dataframe
df.tail()
# Out:
#        longitude  latitude  housing_median_age total_rooms  total_bedrooms  \
# 20635    -121.09     39.48                  25        1665           374.0
# 20636    -121.21     39.49                  18         697           150.0
# 20637    -121.22     39.43                  17        2254           485.0
# 20638    -121.32     39.43                  18        1860           409.0
# 20639    -121.24     39.37                  16        2785           616.0
#
#        population  households  median_income  median_house_value  \
# 20635         845         330         1.5603               78100
# 20636         356         114         2.5568               77100
# 20637        1007         433         1.7000               92300
# 20638         741         349         1.8672               84700
# 20639        1387         530         2.3886               89400
#
#       ocean_proximity
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# ...

# %%
# dtypes function is used to check the data types of the columns in the dataset.
df.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms            object
# total_bedrooms        float64
# population              int64
# households              int64
# median_income         float64
# median_house_value      int64
# ocean_proximity        object
# dtype: object

# %%
# info method is used to show the information of a dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  object
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(4), object(2)
# memory usage: 1.6+ MB

# %%
# Gives an analysis of how the dataframe looks like
df.describe()
# Out:
#           longitude      latitude  housing_median_age  total_bedrooms  \
# count  20640.000000  20640.000000        20640.000000    20433.000000
# mean    -119.569704     35.648344           28.656928      537.870553
# std        2.003532      3.200177           12.848021      421.385070
# min     -124.350000     32.540000            1.000000        1.000000
# 25%     -121.800000     33.930000           18.000000      296.000000
# 50%     -118.490000     34.260000           29.000000      435.000000
# 75%     -118.010000     37.710000           37.000000      647.000000
# max     -114.310000    378.000000          400.000000     6445.000000
#
#          population    households  median_income  median_house_value
# count  20640.000000  20640.000000   20640.000000        20640.000000
# mean    1425.379942    499.539680       3.870623       206855.816909
# std     1132.583966    382.329753       1.899920       115395.615874
# ...

# %%
# Value counts
df['ocean_proximity'].value_counts()
# Out:
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: ocean_proximity, dtype: int64

# %% [markdown]
# # Cleaning of the DataFrame Using Pandas and Numpy

# %%
# isnull function is used to check for missing values in a dataframe
df.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
# Replacing ?? with Numpy NaN in the dataframe
df2 = df.replace(to_replace='??', value=np.NaN)
df2
# Out:
#        longitude  latitude  housing_median_age total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41         880           129.0
# 1        -122.22     37.86                  21        7099          1106.0
# 2        -122.24     37.85                  52        1467           190.0
# 3        -122.25     37.85                  52        1274           235.0
# 4        -122.25     37.85                  52        1627           280.0
# ...          ...       ...                 ...         ...             ...
# 20635    -121.09     39.48                  25        1665           374.0
# 20636    -121.21     39.49                  18         697           150.0
# 20637    -121.22     39.43                  17        2254           485.0
# 20638    -121.32     39.43                  18        1860           409.0
# 20639    -121.24     39.37                  16        2785           616.0
#
#        population  households  median_income  median_house_value  \
# ...

# %%
df2.isnull().sum()
# Out:
# longitude                0
# latitude                 0
# housing_median_age       0
# total_rooms           1018
# total_bedrooms         207
# population               0
# households               0
# median_income            0
# median_house_value       0
# ocean_proximity          0
# dtype: int64

# %%
# Filling the NaN values using the median imputation method.
df3 = df2.fillna(value=df['total_bedrooms'].median())
df3
# Out:
#        longitude  latitude  housing_median_age total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41         880           129.0
# 1        -122.22     37.86                  21        7099          1106.0
# 2        -122.24     37.85                  52        1467           190.0
# 3        -122.25     37.85                  52        1274           235.0
# 4        -122.25     37.85                  52        1627           280.0
# ...          ...       ...                 ...         ...             ...
# 20635    -121.09     39.48                  25        1665           374.0
# 20636    -121.21     39.49                  18         697           150.0
# 20637    -121.22     39.43                  17        2254           485.0
# 20638    -121.32     39.43                  18        1860           409.0
# 20639    -121.24     39.37                  16        2785           616.0
#
#        population  households  median_income  median_house_value  \
# ...

# %%
df3.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms            object
# total_bedrooms        float64
# population              int64
# households              int64
# median_income         float64
# median_house_value      int64
# ocean_proximity        object
# dtype: object

# %%
df3.isnull().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
# Checking for duplicates in the dataframe
df.duplicated().sum()
# Out:
# 0

# %%
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  object
#  4   total_bedrooms      20640 non-null  float64
#  5   population          20640 non-null  int64
#  6   households          20640 non-null  int64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  int64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(4), int64(4), object(2)
# memory usage: 1.6+ MB

# %% [markdown]
# ## Data Visualization

# %%
plt.plot(df3['longitude'], df3['latitude'])
plt.show()

# %% [markdown]
# There seems to be an error in the latitude given in the dataset. This is because the highest latitude on earth is 90 degrees hence the data needs to be cleaned some more.

# %%
# Locating the position of row that has the incorrect data.
df3.loc[df3['latitude'] > 90]
# Out:
#      longitude  latitude  housing_median_age total_rooms  total_bedrooms  \
# 220    -122.21     378.0                  39        2003           500.0
#
#      population  households  median_income  median_house_value ocean_proximity
# 220        1109         464         3.0682              156500        NEAR BAY

# %%
# Replacing the incorrect data with the correct one
df4 = df3.replace(to_replace=378.0, value=37.80)
df4
# Out:
#        longitude  latitude  housing_median_age total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41         880           129.0
# 1        -122.22     37.86                  21        7099          1106.0
# 2        -122.24     37.85                  52        1467           190.0
# 3        -122.25     37.85                  52        1274           235.0
# 4        -122.25     37.85                  52        1627           280.0
# ...          ...       ...                 ...         ...             ...
# 20635    -121.09     39.48                  25        1665           374.0
# 20636    -121.21     39.49                  18         697           150.0
# 20637    -121.22     39.43                  17        2254           485.0
# 20638    -121.32     39.43                  18        1860           409.0
# 20639    -121.24     39.37                  16        2785           616.0
#
#        population  households  median_income  median_house_value  \
# ...

# %%
df4.loc[df4['latitude'] == 37.80]
# Out:
#        longitude  latitude  housing_median_age total_rooms  total_bedrooms  \
# 67       -122.29      37.8                  52        1027           244.0
# 79       -122.28      37.8                  38         684           176.0
# 88       -122.27      37.8                  10         105            42.0
# 89       -122.27      37.8                  52         249            78.0
# 90       -122.27      37.8                  16         994           392.0
# ...          ...       ...                 ...         ...             ...
# 16526    -121.20      37.8                  37         311            61.0
# 16538    -121.22      37.8                  13         335            89.0
# 16544    -121.23      37.8                  11        2451           665.0
# 16556    -121.29      37.8                   6         110            26.0
# 20111    -120.20      37.8                  30        1189           255.0
#
#        population  households  median_income  median_house_value  \
# ...

# %% [markdown]
# From the dataframe, we see that the latitude of the index 220 has been replaced with 37.80 from 378.0

# %%
plt.scatter(x=df4['longitude'], y=df4['latitude'])
plt.xlabel('Longitude')
plt.ylabel('Latitude')

plt.show()

# %%
fig = plt.figure(figsize=(8, 8))
m = Basemap(projection='lcc', resolution='h',
lat_0=37.5, lon_0=-119,
width=1E6, height=1.2E6)
m.shadedrelief()
m.drawcoastlines(color='gray')
m.drawcountries(color='gray')
m.drawstates(color='gray')

m.scatter(df4['longitude'], df4['latitude'], latlon=True, alpha=0.5)

# %% [markdown]
# From this map, it is clear that the location in which the data was obtained is California. The higher and more opaque the dots, the higher the number of houses that were sampled are in that area. The less opaque dots show that less data was obtained from those areas.

# %%
sns.lineplot(data=df4, x=df4['housing_median_age'], y=df4['median_house_value'])
# Out:
# <AxesSubplot:xlabel='housing_median_age', ylabel='median_house_value'>

# %% [markdown]
# Between 1 and 50 years, the median_house_value has been on a relatively upward trend which is like gaining momentum in the markets reaching its highest value of 500001 at 50-52 years of age. After that, the prices decreased steadily. Hence it is safe to say, the older the house gets, the cheaper the price of it.

# %%
# Converting floats to integer
df4['total_rooms'] = df4['total_rooms'].astype(int)
df4['total_rooms']
# Out:
# 0         880
# 1        7099
# 2        1467
# 3        1274
# 4        1627
#          ...
# 20635    1665
# 20636     697
# 20637    2254
# 20638    1860
# 20639    2785
# Name: total_rooms, Length: 20640, dtype: int32

# %%
sns.scatterplot(data=df4, x=df4['median_house_value'], y=df4['population'])
# Out:
# <AxesSubplot:xlabel='median_house_value', ylabel='population'>

# %% [markdown]
# The population seems to be evenly distributed hence the house value is not largely considered when buying houses in California.

# %%
plt.figure(figsize=(15, 8))
plt.scatter(df4['latitude'], df4['longitude'], c= df4['population'], cmap='Spectral', alpha=1.0)
plt.colorbar(label = 'population')
plt.xlabel('latitude')
plt.ylabel('longitude')
plt.clim(1, 10000)

plt.show()

# %% [markdown]
# Most of the houses had a population of 0 to 4000. The colors used to represent the population in that range is pink and brown.

# %%
sns.histplot(data=df4, x=df4['ocean_proximity'], color=('purple'))
# Out:
# <AxesSubplot:xlabel='ocean_proximity', ylabel='Count'>

# %% [markdown]
# The ocean proximity with the highest number of counts that is, 9136, is <1H Ocean followed closely by Inland which has 6551 counts then Near Ocean with 2658, Near Bay has 2290 in the last place is the Island with only 5 counts. The value is small hence it couldn't be captured graphically.

# %%
sns.barplot(data=df4, x=df4['ocean_proximity'], y=df4['population'])
# Out:
# <AxesSubplot:xlabel='ocean_proximity', ylabel='population'>

# %% [markdown]
# The highest populated areas are less than an hour to the ocean, those near the ocean and also the inland area while the least populated area are those near to the bay and the island.

# %%
sns.barplot(data=df4, x=df4['ocean_proximity'], y=df4['median_house_value'], color='green')
# Out:
# <AxesSubplot:xlabel='ocean_proximity', ylabel='median_house_value'>

# %% [markdown]
# The island and areas near the bay have the most expensive houses hence the low population while the inland and the areas close to the ocean have relatively cheaper houses hence the dense population.

# %% [markdown]
# ## Linear Regression
